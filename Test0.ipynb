# %% [markdown]
# <a href="https://colab.research.google.com/github/ernestaa/PSD/blob/main/Test0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Importing  libraries

import numpy as np # linear algebra
import pandas as pd # data processing

# %%
#Importing data

df1=pd.read_csv("https://drive.google.com/file/d/17KyY2IdVBc6eYC1Ogy9mW4BUW-Uuoi6h/view?usp=sharing", sep=',', header=None)
df1.head()
# Out:
#                                                 0     \
# 0  <!doctype html><html lang="en-US" dir="ltr"><h...
# 1  /*# sourceURL=/_/mss/boq-identity/_/ss/k=boq-i...
# 2                       (function(){var c=function(J
# 3                      '(function(){var G=function(d
# 4             Copyright The Closure Library Authors.
#
#                                                 1    2     \
# 0   initial-scale=1"><style data-href="https://ww...   _b
# 1                                                 _b  _tp
# 2                                                  A    u
# 3                                                  J    A
# 4                                                NaN  NaN
#
#                                                 3     \
# 0                                                _tp
# 1  _r */</style><style nonce="ffTczqtDqZ15dsWe2vt...
# 2                                                  d
# 3                                                  z
# ...
